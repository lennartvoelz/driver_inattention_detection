# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
history  = pd.read_csv('../data/history.csv')
#plot history
plt.plot(history['val_accuracy'])
history.head()
# Out:
#         AUC  accuracy      loss  precision   val_AUC  val_accuracy  val_loss  \
# 0  0.780082  0.400000  5.005847   0.520867  0.900274      0.588612  2.938589
# 1  0.888099  0.571042  2.620617   0.649992  0.939825      0.684581  2.099856
# 2  0.919121  0.639063  2.062707   0.700659  0.951182      0.716571  1.714997
# 3  0.935609  0.678750  1.726718   0.732250  0.959255      0.751120  1.489066
# 4  0.944896  0.710938  1.527828   0.757369  0.971217      0.792706  1.303364
#
#    val_precision
# 0       0.769671
# 1       0.753281
# 2       0.784266
# 3       0.783804
# 4       0.844660

# %% [markdown]
# history = pd.readcsv()
